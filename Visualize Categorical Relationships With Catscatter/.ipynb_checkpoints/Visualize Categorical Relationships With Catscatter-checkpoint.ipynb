# %% [markdown]
# ## Visualize Categorical Relationships With Catscatter

# %% [markdown]
# <div><a href=https://towardsdatascience.com/visualize-categorical-relationships-with-catscatter-e60cdb164395>Visualize Categorical Relationships With Catscatter</a></div>
# <div>Credits to <a href=https://towardsdatascience.com/@myrbarnes>Myriam Barnés</a></div>
# <div>Install UDF package <a href=https://github.com/myrthings/catscatter>Github Package</a></div>

# %%
import pandas as pd
import matplotlib as plt
from catscatter import scatter_matrix

# example data frame
data=pd.DataFrame(
    {'friend':['Peter','Marc','Ignacio','Marta','Marta','Ignacio','Maria','Pedro','Bea','Pedro'],
     'favorite_food':['Salmon','Chocolate','Hamburguer','Pizza','Apples','Pizza','Pizza','Hamburguer','Salmon','Banana'],
     'favorite_grade':[1,5,5,3,2,3,4,4,3,1]}
)

#plot it
scatter_matrix(data,'friend','favorite_food','favorite_grade')
# plt.show()

# %%
import pandas as pd
import matplotlib as plt
from catscatter import scatter_matrix

data=pd.DataFrame({'friend':['Peter','Marc','Ignacio','Marta','Marta','Ignacio','Maria','Pedro','Bea','Pedro'],
 'favorite_food':['Salmon','Chocolate','Hamburguer','Pizza','Apples','Pizza','Pizza','Hamburguer','Salmon','Banana'],
 'favorite_grade':[1,5,5,3,2,3,4,4,3,1]})
colors=['green','grey','orange']

scatter_matrix(data,'friend','favorite_food','favorite_grade',color=colors,ratio=100)
